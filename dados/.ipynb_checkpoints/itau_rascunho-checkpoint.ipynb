# %%
import pandas as pd
import numpy as np
import re
import string
from unidecode import unidecode
import nltk
import os


# Aqui os .txt estao dentro da pasta loop
files = os.listdir('loop') # mudar para o diretorio que tenha todos os .txt dos tweets
lista_pandas = list()
regex = re.compile(r'(?<=tweets_)[a-zA-Z\s]{2,}')

for file in files:
    d = pd.read_csv(os.path.join('loop',file), sep="\t")
    d['tag'] = regex.search(file).group()
    lista_pandas.append(d)

data = pd.concat(lista_pandas)
data.reset_index(drop=True, inplace=True)
print(data.shape)
# se gerar erro, abrir o .txt no notepad e salvar em UTF-8
# Out:
# (15004, 10)

# %%
data.head(10)
# Out:
#            Unnamed: 0                 data                usuario  \
# 0  984258197073596416  2018-04-12 02:33:35             merespeita
# 1  984257326763986944  2018-04-12 02:30:07          Desidrogenase
# 2  984256477929050112  2018-04-12 02:26:45        Diego Souza CRF
# 3  984256454004797440  2018-04-12 02:26:39     Revista CanaOnline
# 4  984255454862807040  2018-04-12 02:22:41                cecilia
# 5  984255381772881920  2018-04-12 02:22:24             Tainazinha
# 6  984255089039872000  2018-04-12 02:21:14            L. A.Vieira
# 7  984254286363283456  2018-04-12 02:18:03               sorvete?
# 8  984253161765593088  2018-04-12 02:13:34             Tainazinha
# 9  984250693103112192  2018-04-12 02:03:46  Antonio Lula Bregensk
#
#                                             conteudo  retweets  favoritos  \
# 0  @MrPoladoful nossa men se quer saber vendo la ...       0.0        0.0
# 1  @DivagoTM Na verdade a piada aí é que alguém c...       0.0        1.0
# 2  Guerra, Moisés e William eram opções de banco ...       0.0        4.0
# 3  A 5ª edição do Agroencontro, organizado de 10 ...       0.0        0.0
# 4  @GustavoCubas28 eu consigo pelo meu do banco d...       0.0        0.0
# 5  O banco do Brasil ficou todo destruído https:/...       0.0        0.0
# 6  RT @marisascruz: Partidos que ODEIAM o Brasil ...      66.0        0.0
# 7  RT @wheewoon: aí a pessoa manda bb e eu não se...       1.0        0.0
# 8  Assaltaram o banco do Brasil aqui no meu país ...       0.0        1.0
# 9  RT @rogeriotomazjr: O maior banco do Brasil e ...      34.0        0.0
#
#   local  seguidores  amigos              tag
# 0   NaN         0.0    70.0  banco do brasil
# 1   NaN       118.0   343.0  banco do brasil
# 2   NaN      3156.0   619.0  banco do brasil
# 3   NaN       527.0    16.0  banco do brasil
# 4   NaN       151.0   196.0  banco do brasil
# 5   NaN      1067.0  1662.0  banco do brasil
# 6   NaN       228.0    83.0  banco do brasil
# 7   NaN       352.0   315.0  banco do brasil
# 8   NaN      1067.0  1662.0  banco do brasil
# 9   NaN         5.0    17.0  banco do brasil

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15004 entries, 0 to 15003
# Data columns (total 10 columns):
# Unnamed: 0    15004 non-null object
# data          15003 non-null object
# usuario       15002 non-null object
# conteudo      15000 non-null object
# retweets      15000 non-null float64
# favoritos     15000 non-null float64
# local         543 non-null object
# seguidores    14997 non-null float64
# amigos        14997 non-null float64
# tag           15004 non-null object
# dtypes: float64(4), object(6)
# memory usage: 1.1+ MB

# %%
# Criando uma coluna com as contas citadas no campo conteudo @...
regex = re.compile(r'@([^\s]+)') 
data['citados'] = data['conteudo'].apply(lambda x: regex.findall(str(x)))
data['n_citados'] = data['citados'].apply(lambda x: len(x))
data['citados'] = data['citados'].apply(lambda x: ' '.join(x) if isinstance(x, list) else np.NaN)
data['citados'] = data['citados'].apply(lambda x: x.strip(string.punctuation))
data['citados'] = data['citados'].apply(lambda x: x.lower())


# Aqui pego todos os tweets que tenham citado itau e os que vem da tag itau
#filtro = pd.concat([data[data['citados'].str.contains('itau')], data[data.tag=='itau']])
filtro = data[data['citados'].str.contains('itau')]

filtro = filtro[filtro.n_citados<6] # n_citados > 6 possivelmente spam 
#(temos que confirmar via estatisticas e/ou treino destes dados)

filtro.shape # Valor baixo, mas me parece um bom filtro inicial (?) 
# Alternativas -> Coletar mais dados
# Realizar filtros com a tag itau tb ->>>> data[data.tag=='itau'] <<<- porem dera duplicatas
# Out:
# (573, 12)

# %%
for a in filtro['conteudo']:
    print(a)
# Out:
# @cfs_claudia @itau @BancodoBrasil @Bancointer @Caixa Tinha que ser a CEF.
# RT @cfs_claudia: Isso não acontece no @itau, nem no @BancodoBrasil, muito menos no @Bancointer, aliás, pessoas que estão ler, abram conta n…
# Isso não acontece no @itau, nem no @BancodoBrasil, muito menos no @Bancointer, aliás, pessoas que estão ler, abram… https://t.co/ni0ijxwdux
# @itau E aí @BancodoBrasil e @Bancointer vão continuar atrás do Itaú ou vão tentar, pelo menos, acompanhar?!
# @RAFAELACAMPOS8 @itau @Bancointer @banco24horas Aqui é roça. Tinha um 24hs mas roubaram kkkkkkkkkkkk
# @RAFAELACAMPOS8 @itau @Bancointer @banco24horas Tô investindo na NuConta do @nubank quando sobra alguma coisa kkkk… https://t.co/pNs99y3Yqm
# @pedro_mourao @itau @Bancointer Sim, mas as opções de investimento do Inter com certeza são melhores que as ofereci… https://t.co/2WxzC7qnhV
# @RAFAELACAMPOS8 @itau @Bancointer A iConta do @itau é sensacional! Pode sacar a vontade nos caixas eletrônicos, faz… https://t.co/GHjZ5uYv6q
# @pedro_mourao @itau iConta é a conta digital do Itau? Já experimentou o @Bancointer?
# @StanleySathler @itau Verdade. Por isso que eu mudei pro @Bancointer. Muito melhor, prático e digital ?
# Quero dar um pontapé no @itau mas o @Bancointer não deixa! pediu mais 180 dias para a minha conta PRO :( - Estou mi… https://t.co/65Clx3h6kg
# Não indico o @itau nem para a pessoa que eu mais odeio e quero que sofra na vida pq pra quase tudo tem limites, men… https://t.co/vxodIpos9f
# @chrisptoferxsd4 @itau Abre no @Bancointer .... Vai acabar seus problemas.. e ainda .. taxa 0!!!
# @itau Resposta dada, meio mais do mesmo mas respondi de volta. Aguardar fazer o que. Ah, quando o @SamsungPay da… https://t.co/Rn3F8UzZIM
# @Tiagocsilva96 @meudigio @Bancointer @nubank @itau Sofri muito no passado com o Itaucard, mas agora é tudo tão prát… https://t.co/v5JafIOtu3
# @heitorzilla @meudigio @Bancointer @nubank @itau Eu estava a um passo de fazer a maior cagada da minha vida, pedir… https://t.co/dCR1veHk3e
# @ofabiofarias @itau @Bancointer @Bancointer top! O melhor...
# Fez bem amigo.
# #MudancasSaoBemVindas
# @itau Ocorreu que meu cpf está negativado pelo Itaú, por um débito que já foi pago, e vocês estão ligando e enviand… https://t.co/iJdy03KBmV
# RT @Fabiosorbite: @o_antagonista ??Um deles é o @itau , eu me lembro de um amigo falecido “Edson” que era da diretoria do Itaú, nos contou…
# @o_antagonista ??Um deles é o @itau , eu me lembro de um amigo falecido “Edson” que era da diretoria do Itaú, nos c… https://t.co/AbAY238LLZ
# Aquele momento que você cansa de ir no banco mais picareta, vulgo @itau , pra resolver as coisas e prefere poupar o… https://t.co/lpwws2LvO0
# @itau Podemos fazer por DM?
# @itau Ok, estou respondendo por lá
# Acho que o @santander_br, o @itau e o @Bradesco fazem uma disputa pra ver qual deles tem o pior atendimento
# @RealEden @itau Entendi, eu tive essa sorte esses anos todos.. mas com outros bancos não. Fuji do Santander e CEF..… https://t.co/DIRSZ8Apo6
# @itau Quando estará disponível para Android? O SamsungPay é utilizado pelo BB, Bradesco, Santander, entre outros.
# RT @samucaurelio: @itau Libera o Apple Pay também @santander e não apaga mais o TT
# @itau Libera o Apple Pay também @santander e não apaga mais o TT
# @santander_br  vocês podem liberar o Apple Pay igual o
# @itau fez, obrigado
# @santander_br você é melhor que @itau
# @itau Ai @santander_br  foi isso que eu pedi, não que me vendessem um cartãozinho de plástico!!!
# @itau Preciso de um seguro pro meu carro eu tinha do Santander mais não quero mais por eles
# @itau O @santander_br já tem isso a muito tempo. Como sempre o @itau chegando atrasado.
# @taigatondorf @itau Sou cliente do Santander, a minha gerente é mt maravilhosa pelo menos, ela já me entregou meu c… https://t.co/DFS7bAVjDg
# @marcelofs1 @itau @santander_br É outro caso. Não tem nada a ver mesmo.
# @prissguerrero1 @itau @santander_br te deixaram em paz porque venderam a lista pro Itaú ?
# @marcelofs1 @itau @santander_br Não. Situação diferente. E o Satander parou de me encher. Estamos em#paz.
# @prissguerrero1 @itau está claro que eles trocam figurinhas com o @santander_br
# Todos os bancos estão com problema hoje? @itau não efetivou boletos agendados dia 10, @bancosafra e @santander_br c… https://t.co/55wDnPniCT
# @santander_br @santander_br aprende com o @itau
# Eu perdi meu cartão na época de greve, ele pediram meu numero, me… https://t.co/51BD5j6ox5
# @santander_br o app de vocês é um lixo. nunca pensei que ia sentir saudades do @itau ??
# Acho que o @santander_br, o @itau e o @Bradesco fazem uma disputa pra ver qual deles tem o pior atendimento
# @RealEden @itau Entendi, eu tive essa sorte esses anos todos.. mas com outros bancos não. Fuji do Santander e CEF..… https://t.co/DIRSZ8Apo6

# %%
# Criando uma coluna com as hashtags no campo conteudo #...

#hashtag = re.compile(r'#([^\s]+)')
#data['hashtag'] = data['conteudo'].apply(lambda x: hashtag.findall(x))
#data['hashtag'] = data['hashtag'].apply(lambda x: ' '.join(x) if isinstance(x, list) else np.NaN)
#data['hashtag'] = data['hashtag'].apply(lambda x: x.strip(string.punctuation))

# %%
# Outra tentativa de extrair informação

# Pegando valores unicos
data.apply(pd.Series.nunique, axis=0)
# Como conteudo eh o que importa, vamos analisar somente seus valores unicos

conteudo = data['conteudo']
conteudo = pd.DataFrame({'conteudo': conteudo})
conteudo['citados'] = conteudo['conteudo'].apply(lambda x: regex.findall(str(x)))
conteudo['citados'] = conteudo['citados'].apply(lambda x: ' '.join(x) if isinstance(x, list) else np.NaN)
conteudo['citados'] = conteudo['citados'].apply(lambda x: x.strip(string.punctuation))
conteudo['citados'] = conteudo['citados'].apply(lambda x: x.lower())
conteudo['n_citados'] = conteudo['citados'].apply(lambda x: len(x.split()))

# %%
import string
import unidecode
import re
import unidecode
import nltk
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd

def preprocess_text(raw_corpus):
    raw_corpus = raw_corpus.str.replace('[\r\n]',' ')
    pt_stopwords = set([unidecode.unidecode(i) for i in nltk.corpus.stopwords.words('portuguese')])    
    pt_stopwords = pt_stopwords.union(['rt','via'])
    def preprocess(x, *stopwords_list):
        x = unidecode.unidecode(re.sub(r'(?:@[\w_]+)', '', str(x)))# eliminando os valores com @.. (citacoes)
        x = unidecode.unidecode(re.sub(r'http[s]?://.+[^\s]', '', str(x)))
        stemmer = nltk.stem.RSLPStemmer()
        x = unidecode.unidecode(re.sub('['+string.punctuation+'«»'+']', ' ', x.lower()))
        x = [stemmer.stem(w) for w in x.split() if w not in set(pt_stopwords)]
        return ' '.join(x)

    clean_text = raw_corpus.apply(preprocess, args = pt_stopwords)
    clean_text = clean_text.str.replace('\d+', '')
    return clean_text

def preprocess_text_fasttext(raw_corpus):
    raw_corpus = raw_corpus.str.replace('[\r\n]',' ')  
    def preprocess(x):
        x = re.sub('['+string.punctuation+'«»'+']', ' ', x.lower())
        x = re.sub('[ ]{2,}', ' ', x.lower()).strip()
        return x

    clean_text = raw_corpus.apply(preprocess)
    clean_text = clean_text.str.replace('\d+', '')
    return clean_text

def get_word_freq(data):
    count_vectorizer = CountVectorizer().fit(data)
    class_bow = count_vectorizer.transform(class_news)
    class_vocab = list(count_vectorizer.get_feature_names())
    counts = class_bow.sum(axis=0).A1
    class_word_counts = pd.DataFrame(list(dict(zip(class_vocab, counts)).items()), 
                                   columns = ['word','freq']).sort_values('freq', ascending = False)
    return class_word_counts

# %%
cleantext = preprocess_text(conteudo['conteudo'])
cleantext
# Out:
# 0        men qu sab vend la cas papel pens hen rob banc...
# 1        verdad pi ai algu conseg pass dec forag escond...
# 2        guerr mois will opco banc hoj palm elenc porc ...
# 3        a edica agroencontr organiz   abril ourofin ag...
# 4                                       consig banc brasil
# 5                               banc brasil fic tod destru
# 6        part ode brasil pov brasil pcdob psol pdt psb ...
# 7        ai pesso mand bb sei ta fal bigbang block b ba...
# 8        assalt banc brasil aqu pal pass to acredit ago...
# 9        mai banc brasil o mund conseg reduz condenaca ...
# 10                                             banc brasil
# 11       ai fod client ne gent comissari voo azar ter a...
# 12       amig cumpr fez taref chat pass sacol p fech co...
# 13       banc brasil deix patrocin handebol ampl cris cbhb
# 14                                 tip lig pro banc brasil
# 15         banc brasil agenc cas inclusiv horari funcion p
# 16       internet banking banc brasil aceit pag feri fi...
# 17                           vam dar golp banc brasil bent
# 18       precis dess dinh segund feir quer volt pra rua...
# 19       amig cumpr fez taref chat pass sacol p fech co...
# 20          critic miss bernard camp sobr sequ moral moral
# 21                                               gost vide
# 22       amig cumpr fez taref chat pass sacol p fech co...
# 23       mai banc brasil o mund conseg reduz condenaca ...
# 24                   int parec tim aposent banc brasil bol
# 25          critic miss bernard camp sobr sequ moral moral
# 26                   int parec tim aposent banc brasil bol
# 27          critic miss bernard camp sobr sequ moral moral
# 28       amig cumpr fez taref chat pass sacol p fech co...
# 29       precis dess dinh segund feir quer volt pra rua...
#                                ...
# 14974                   banc santand mot yamah beb bud etc
# 14975                             nunc consegu fal santand
# 14976          abr cont fal ident ilegi mesm abr cont itau
# 14977                          thal atend consegu abr cont
# 14978    lhonard pod renegoci debit conosc atrav centr ...
# 14979                 fac habil id santand apresent codig
# 14980    icon ativaca pag celul sum app determin tip ca...
# 14981                           luiz acontec poss ajud aqu
# 14982        ai vald puls sup pra rap ne qualqu duvid avis
# 14983                      la santand sistem desd ont banq
# 14984    engrac respeit nenhum client real desculp palavre
# 14985           paul detalh orient contat centr atend pj
# 14986                 quer contat pud agiliz negociaca div
# 14987    amig cumpr fez taref chat pass sacol p fech co...
# 14988    ana pec gentil interaj respeit cas send analis...
# 14989        entend sort ano tod outr banc fuj santand cef
# 14990    pesso acab cont pra coleg vim espirit santand ...
# 14991                                         i liked vide
# 14992                                          pesso jurid
# 14993       paul ref internet banking sim cont pesso jurid
# 14994            tip exempl aca funcionari aposent banesp
# 14995                  marci acontec algum dad cadastr err
# 14996    relaca app orient desinstal instal nov err per...
# 14997    unicamp agenc cad banc santand bb circul pass ...
# 14998                           murill atend poss ajud aqu
# 14999    mex cont santand desd  prim chut acert senh kk...
# 15000                                     regin precis aqu
# 15001                                                 part
# 15002    ant encerr cont santand precis sac grand quant...
# 15003    santand patrocin pra ir pra sair recif ir pra ...
# Name: conteudo, dtype: object

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(ngram_range=(2,2)).fit(cleantext)
raw_vector = tfidf.transform(cleantext)
counts = raw_vector.sum(axis=0).A1
vocab = list(tfidf.get_feature_names())

pd.DataFrame(list(dict(zip(vocab, counts)).items()), 
             columns = ['word','freq']).sort_values('freq', ascending = False)
# Out:
#                    word        freq
# 3644        banc brasil  253.673760
# 19830         milho mil  234.600223
# 13831         fech cont  196.455003
# 10314           dest me  195.581730
# 19263           me cont  195.571203
# 9362          cumpr fez  195.502917
# 27629        sacol fech  195.502917
# 20412          mvb dest  195.502917
# 30118        taref chat  195.502917
# 7014          chat pass  195.502917
# 23036        pass sacol  195.502917
# 14041         fez taref  195.502917
# 1940         amig cumpr  195.502917
# 8569           cont mvb  195.502917
# 5013       brad santand  170.734691
# 4514           boc caix  165.108116
# 18399     lindbergh far  164.927249
# 16499    inquerit contr  164.628882
# 8812    contr lindbergh  164.628882
# 13503        far depend  164.628882
# 9918   depend informaco  164.468955
# 29303         sobr saqu  164.468955
# 28103          saqu boc  164.468955
# 28059      santand sobr  164.468955
# 16438    informaco brad  164.468955
# 8065    condenaca milho  139.290113
# 15280         gost vide  136.000000
# 26751   reduz condenaca  117.162814
# 3767           banc lix  101.588411
# 18465        lix caralh  101.426564
# ...                 ...         ...
# 7393          client gt    0.251060
# 7311            cl unic    0.251060
# 32261       val ingress    0.244433
# 7276          cinem pra    0.244433
# 1892         amanh fiqu    0.244433
# 23760             pf kk    0.244433
# 14330       fiqu vontad    0.244433
# 31944             us pf    0.244433
# 16472       ingress pra    0.244433
# 7562          codig val    0.244433
# 1210           ai codig    0.244433
# 31906          us amanh    0.244433
# 3528            avis us    0.244433
# 33477       vontad avis    0.244433
# 20125       mort vontad    0.236758
# 27598          sac itau    0.236758
# 6046         cant icaru    0.236758
# 26375         rapaz sac    0.236758
# 33479       vontad cant    0.236758
# 15958         icar mort    0.236758
# 15667          hoj cham    0.236758
# 15960          icaru is    0.236758
# 31026            to the    0.236758
# 16909         is flying    0.236758
# 6964          cham icar    0.236758
# 30761           the sun    0.236758
# 14453        flying too    0.236758
# 31204          too clos    0.236758
# 7449            clos to    0.236758
# 29704       sun telefon    0.236758
#
# [33734 rows x 2 columns]

# %%
raw_vector
# Out:
# <15004x33734 sparse matrix of type '<class 'numpy.float64'>'
# 	with 108415 stored elements in Compressed Sparse Row format>

# %%
from sklearn.cluster import KMeans

clf = KMeans(n_clusters = 20)
clf.fit(raw_vector)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=20, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
tfidf.inverse_transform(clf.cluster_centers_)
# Out:
# [array(['afast odil', 'ajud banc', 'ato sane', 'banc bras', 'banc perdo',
#         'banc vatic', 'barr votaco', 'brasil estada', 'brasil pcdob',
#         'brasil pov', 'car client', 'carde ato', 'chequ espec',
#         'client itau', 'dess dinh', 'dinh segund', 'espec banc',
#         'feir quer', 'inclu auton', 'inclu autonom', 'itau ve', 'jur chequ',
#         'ode brasil', 'odil carde', 'pap afast', 'part ode', 'pcdob psol',
#         'pdt psb', 'perdo process', 'pov brasil', 'pra rua', 'precis dess',
#         'psb pt', 'psol pdt', 'pt vao', 'qualqu val', 'quer volt',
#         'rua qualqu', 'sane banc', 'segund feir', 'tax jur', 'val ajud',
#         'vao barr', 'vatic brasil', 've tax', 'volt pra', 'votaco inclu'],
#        dtype='<U57'),
#  array(['boc caix', 'brad santand', 'caix http', 'caix sen',
#         'contr lindbergh', 'depend informaco', 'far depend',
#         'informaco brad', 'inquerit contr', 'lindbergh far', 'santand sobr',
#         'saqu boc', 'sobr saqu'],
#        dtype='<U57'),
#  array(['gost vide'],
#        dtype='<U57'),
#  array(['amig cumpr', 'chat pass', 'cont mvb', 'cumpr fez', 'dest me',
#         'fech cont', 'fez taref', 'me cont', 'mvb dest', 'pass sacol',
#         'sacol fech', 'taref chat'],
#        dtype='<U57'),
#  array(['brad kkkkkk', 'brinc brad'],
#        dtype='<U57'),
#  array(['aaa brasil', 'aaa vai', 'aaaa corinth', ..., 'zoom tav', 'zu gal',
#         'zuer preench'],
#        dtype='<U57'),
#  array(['aliment banc', 'banc dad', 'brasil vc', 'continu mand', 'dad glob',
#         'futur aliment', 'mand vide', 'manipul continu', 'pro futur',
#         'qu pro', 'vc qu', 'vide brasil'],
#        dtype='<U57'),
#  array(['caix itau', 'cap pag', 'caruaru pe', 'cbx magic',
#         'deposit transferenc', 'dia utel', 'escolh cap', 'eunapolil ba',
#         'feir sant', 'filh ba', 'fortal ce', 'freit ba', 'fret dia',
#         'guararap pe', 'itau sicoob', 'itau unibanc', 'jaboata guararap',
#         'juaz ba', 'macei al', 'magic fret', 'maracanau ce', 'natal rn',
#         'pag deposit', 'recif pe', 'salv ba', 'sant ba', 'simo filh',
#         'sobr ce', 'teix freit', 'transferenc caix', 'unibanc aracaju',
#         'unibanc caruaru', 'unibanc eunapolil', 'unibanc feir',
#         'unibanc fortal', 'unibanc jaboata', 'unibanc juaz',
#         'unibanc macei', 'unibanc maracanau', 'unibanc natal',
#         'unibanc recif', 'unibanc salv', 'unibanc simo', 'unibanc sobr',
#         'unibanc teix', 'utel escolh', 'vag caix'],
#        dtype='<U57'),
#  array(['abert cont', 'acess app', 'acess cont', 'acess pod', 'acim pod',
#         'acompanh carta', 'acontec carta', 'acontec dm', 'acontec pod',
#         'adri pod', 'agenc con', 'agradec sugesta', 'ah vam', 'aind algum',
#         'aind critic', 'ajud acompanh', 'ajud aind', 'ajud alg',
#         'ajud algum', 'ajud anex', 'ajud aqu', 'ajud cert', 'ajud compr',
#         'ajud contacomag', 'ajud contaprag', 'ajud cuid', 'ajud favor',
#         'ajud mand', 'ajud obrig', 'ajud precis', 'ajud pro', 'ajud prod',
#         'ajud quis', 'ajud resolv', 'ajud send', 'ajud sim', 'ajud sobr',
#         'ajud tent', 'ajud twitt', 'ajud wagn', 'alan pod', 'alg env',
#         'algu pod', 'algum ajud', 'algum compr', 'algum form', 'algum outr',
#         'alter pod', 'alteraca limit', 'alys lament', 'alysson pod',
#         'ana tent', 'andr qual', 'anex tod', 'angel lament',
#         'aniversari mai', 'antoni possu', 'app pod', 'app sit', 'aqu carta',
#         'aqu cas', 'aqu cham', 'aqu detalh', 'aqu pod', 'aqu possi',
#         'aqu prefer', 'aqu questa', 'atend gross', 'atend pod',
#         'atrav codig', 'automa instituico', 'banc serv', 'bem motiv',
#         'bem pod', 'betim pod', 'boa noit', 'boa tard', 'bom dia',
#         'box sobr', 'brad to', 'brun pod', 'cai pod', 'caix eletron',
#         'camil pod', 'canal quer', 'carl lament', 'carl pod', 'carta atrav',
#         'carta cont', 'carta credit', 'carta juupit', 'carta pod',
#         'cas poss', 'cas pref', 'centr proposit', 'cert pod', 'ceu cont',
#         'cham dm', 'cham gent', 'chat ngm', 'cinc pi', 'clar adri',
#         'clar alysson', 'clar pod', 'client pod', 'codig rastr',
#         'coloc sinal', 'combin fern', 'compr ex', 'compr pod',
#         'confirming vc', 'consegu acess', 'consegu entr', 'consegu resolv',
#         'cont credit', 'cont itau', 'cont ont', 'cont pod', 'cont pra',
#         'cont pro', 'contaprag acontec', 'contaprag pod', 'contat centr',
#         'conveni debit', 'conveni tip', 'convers dm', 'credit atend',
#         'cri cont', 'dan tud', 'debit automa', 'dem atend', 'deposit fiq',
#         'descobr caix', 'descont refer', 'desd me', 'detalh acontec',
#         'detalh dificuldad', 'detalh dm', 'deu err', 'deu tud',
#         'dia acontec', 'dia pequen', 'dia pod', 'dificuldad encontr',
#         'diretriz process', 'disponibil tip', 'disposica jean', 'dm detalh',
#         'dm inform', 'dm pod', 'dm pra', 'dm resolv', 'dm solicitaca',
#         'dm verific', 'document abert', 'duvid pod', 'ei alan', 'ei alys',
#         'ei andr', 'ei angel', 'ei antoni', 'ei betim', 'ei boa', 'ei cai',
#         'ei carl', 'ei clar', 'ei elien', 'ei fern', 'ei franci',
#         'ei gabriel', 'ei gui', 'ei jr', 'ei lament', 'ei luan', 'ei luc',
#         'ei luiz', 'ei pod', 'ei rafael', 'ei thiag', 'ei tud',
#         'ei virgili', 'ei vitt', 'ei wesley', 'eletron deu', 'eletron hor',
#         'elien tud', 'encontr utiliz', 'enfrent carta', 'entend melhor',
#         'entr app', 'env dm', 'envi dm', 'err deposit', 'esper gerent',
#         'esper pod', 'estagiari pod', 'ex box', 'experienc nega',
#         'explic melhor', 'expliqu melhor', 'fatur vc', 'fern boa',
#         'fern cas', 'fern pod', 'fic fil', 'fil esper', 'fiq hor',
#         'fiqu raiv', 'flavi pod', 'form aqu', 'form cham',
#         'form contacomag', 'form disposica', 'form expliqu', 'form lament',
#         'form marc', 'franci pod', 'gabriel pod', 'gent aqu', 'gent dm',
#         'gent luan', 'gent pod', 'gent priv', 'gent resolv', 'gerent pod',
#         'gross lig', 'gui lament', 'guilherm diretriz', 'help pod',
#         'hor esper', 'hor pag', 'ig precis', 'infeliz vou',
#         'inform numeraca', 'inform pod', 'informaco toa', 'ingrid pod',
#         'instituico acim', 'invest pod', 'itau pod', 'johnny pod',
#         'jon pod', 'jr pod', 'juupit pod', 'lament dem', 'lament experienc',
#         'lament situaca', 'lament transtorn', 'lembr senh', 'lig gent',
#         'limit opca', 'luan pod', 'luc cas', 'luc previsa', 'luiz pod',
#         'lumin ceu', 'mai numer', 'mail por', 'mand msg', 'marc cham',
#         'me pass', 'melhor acontec', 'melhor ocorr', 'melhor pod',
#         'mem possi', 'migraca cont', 'mil pod', 'motiv camil',
#         'motiv consegu', 'motiv gent', 'msg chat', 'msg dm', 'nand msg',
#         'nathal pod', 'necess client', 'nega banc', 'ngm respond',
#         'niss infeliz', 'noit acontec', 'noit nand', 'noit pod',
#         'noit segu', 'numer mail', 'numer mem', 'numeraca agenc',
#         'ocorr migraca', 'ocorr pod', 'oi boa', 'oi bom', 'oi brad',
#         'oi camil', 'oi dan', 'oi ig', 'oi ingrid', 'oi mil', 'oi motiv',
#         'oi nathal', 'oi ocorr', 'oi pedr', 'oi pod', 'oi pra', 'oi sad',
#         'ola carl', 'ola flavi', 'ola guilherm', 'ola johnny', 'ola jon',
#         'ola luiz', 'ola paul', 'ola pod', 'ola rodrig', 'ola samuel',
#         'ola thiag', 'ola tiag', 'ola vc', 'omit informaco', 'ond pod',
#         'ont problem', 'opca alter', 'outr form', 'pabl lament',
#         'padra banc', 'pag algum', 'pag fatur', 'part invest',
#         'pass alteraca', 'pass atend', 'pass numer', 'patrick tip',
#         'paul pod', 'pedr tud', 'pens pod', 'pequen problem',
#         'personal carta', 'pi banc', 'pod ajud', 'pod convers',
#         'pod explic', 'pod personal', 'por fic', 'poss ajud', 'possi cham',
#         'possu conveni', 'pox fiqu', 'pox motiv', 'pox niss', 'pra gent',
#         'pra telefon', 'precis algum', 'precis coloc', 'precis help',
#         'pref cham', 'prefer cham', 'prefer detalh', 'previsa disponibil',
#         'prim acess', 'pro aind', 'pro aqu', 'problem algu', 'problem desd',
#         'problem enfrent', 'problem pag', 'problem part', 'problem pod',
#         'problem prim', 'problem tend', 'problem urgent', 'process padra',
#         'program pod', 'proposit pod', 'qual problem', 'quer entend',
#         'quer lembr', 'questa carta', 'quis pod', 'rafael lament',
#         'raiv gent', 'rayss pod', 'refer quer', 'relaca pod',
#         'renegociaca canal', 'resolv mai', 'resolv problem',
#         'resolv relaca', 'resolv situaca', 'resolv tud', 'rodrig pod',
#         'sab ond', 'sad pod', 'samuel pod', 'segu pass', 'send transpar',
#         'senh acess', 'serv necess', 'sinal lumin', 'sit pod',
#         'situaca contaprag', 'situaca pod', 'sobr aniversari', 'sobr carta',
#         'sobr trat', 'solicitaca pod', 'sort descobr', 'sugesta luc',
#         'tard acontec', 'tard consegu', 'tard pod', 'tard sobr',
#         'tax inform', 'telefon tent', 'tend pod', 'tent contat', 'tent lig',
#         'tent renegociaca', 'tent resolv', 'thiag lament', 'thiag pod',
#         'tiag consegu', 'tic pod', 'tip cont', 'tip descont', 'tip program',
#         'to precis', 'to problem', 'toa cinc', 'toc ah', 'tod document',
#         'transpar omit', 'transtorn brun', 'transtorn pod', 'transtorn tic',
#         'trat tax', 'tud bem', 'tud cert', 'twitt gent',
#         'urgent confirming', 'utiliz itoken', 'vam resolv', 'vc pod',
#         'verific favor', 'virgili pod', 'vitt pod', 'vou pod', 'wesley qual'],
#        dtype='<U57'),
#  array(['ai falan', 'banc brasil', 'brasil mund', 'condenaca milho',
#         'conseg reduz', 'mai banc', 'mil ai', 'milho mil', 'mund conseg',
#         'reduz condenaca'],
#        dtype='<U57'),
#  array(['aplicaca banc', 'aplicaca val', 'banc int', 'bem canet',
#         'boa vind', 'brenn canet', 'brun canet', 'canet envi',
#         'client soment', 'david canet', 'dudu tud', 'ei brenn', 'ei brun',
#         'ei canet', 'ei david', 'ei dudu', 'ei felip', 'ei gut', 'ei jos',
#         'ei lenald', 'ei math', 'ei mei', 'ei shi', 'ei tainah',
#         'envi client', 'felip canet', 'guilherm canet', 'gut canet',
#         'int va', 'int val', 'isac canet', 'jos canet', 'kit boa',
#         'lenald canet', 'math canet', 'mei kit', 'oi yohann',
#         'ola guilherm', 'ola isac', 'prim aplicaca', 'shi canet',
#         'soment prim', 'tainah canet', 'tud bem', 'vind envi',
#         'yohann canet'],
#        dtype='<U57'),
#  array(['aca cole', 'alegr seg', 'cole milho', 'condenaca milho',
#         'desconfi itau', 'estranh desconfi', 'firm itau', 'gost sab',
#         'itau obt', 'luil nassif', 'mil gost', 'mil stj', 'milho mil',
#         'nassif itau', 'obt reduca', 'reduca condenaca', 'reduca val',
#         'retweeted luil', 'seg firm', 'stj ggn', 'tr alegr', 'val aca'],
#        dtype='<U57'),
#  array(['amig atual', 'atual sucess', 'configuraco siti', 'defês palocc',
#         'diz fo', 'palocc diz', 'siti amig', 'sucess defês'],
#        dtype='<U57'),
#  array(['bbd stf', 'brad http', 'cas envolv', 'envolv bbd', 'fal sobr',
#         'sobr cas', 'stf brad'],
#        dtype='<U57'),
#  array(['agor appl', 'agor judiciari', 'appl pay', 'bi itau', 'car pra',
#         'dar um', 'div bi', 'facil rap', 'fic facil', 'govern perdo',
#         'hipst vontad', 'itau agor', 'itau appl', 'judiciari tam',
#         'ment prior', 'pag fic', 'pag uau', 'pay pag', 'pay tant',
#         'perdo div', 'pra vir', 'prior govern', 'propagand itau',
#         'rap segur', 'segur impression', 'tant hipst', 'tap car',
#         'uau itau', 'um tap', 'vir gent', 'vontad dar'],
#        dtype='<U57'),
#  array(['agenc pq', 'descalc agenc', 'entr descalc', 'pq preg',
#         'preg chinel'],
#        dtype='<U57'),
#  array(['banc lix', 'lix caralh'],
#        dtype='<U57'),
#  array(['acess pod', 'adiant entr', 'adri poss', 'agenc apo', 'agenc centr',
#         'ai diz', 'aind chav', 'ajud pod', 'algum question', 'amig entr',
#         'and pod', 'andr precis', 'anteri vc', 'aparelh anteri',
#         'apo etern', 'aqu acess', 'assim posicion', 'atend assim',
#         'atend conseg', 'atend numer', 'atend qua', 'atrav dm', 'avis entr',
#         'banc bloquei', 'banc brasil', 'banc centr', 'banc itau',
#         'bande cart', 'bb car', 'bem orient', 'black pod', 'bloquei carta',
#         'boa noit', 'bobby numer', 'brasil fal', 'bren cas',
#         'cadastr aparelh', 'caiqu pod', 'car con', 'carl numer',
#         'carta platinum', 'carta possu', 'carta solicit', 'carto credit',
#         'cas algum', 'cas equip', 'cas necessari', 'cas vc', 'centr atend',
#         'centr cas', 'centr fara', 'centr fon', 'centr opc',
#         'cert desbloqu', 'chat resolv', 'chav cadastr', 'cheg entr',
#         'cobr tax', 'codig invest', 'comercializ plan', 'comig diss',
#         'condico walt', 'conosc atrav', 'conosc dm', 'conosc vam',
#         'consegu entr', 'contat agenc', 'contat banc', 'contat bande',
#         'contat carl', 'contat cent', 'contat centr', 'contat co',
#         'contat comig', 'contat conosc', 'contat dm', 'contat equip',
#         'contat gent', 'contat mail', 'contat numer', 'contat obrig',
#         'contat oferec', 'contat orga', 'contat prime', 'contat sab',
#         'contat sac', 'contat sim', 'contat sit', 'contat vc',
#         'credit cert', 'dad banc', 'desbloqu tent', 'detalh sobr',
#         'dia problem', 'diss doi', 'div entr', 'diz precis', 'dm ok',
#         'dm vam', 'doi dia', 'ei caiqu', 'ei lex', 'ei pedr', 'ei pod',
#         'ei tiag', 'empr entr', 'empurr problem', 'entr contat',
#         'envi carta', 'equip centr', 'equip sobr', 'etern atend',
#         'facil verific', 'fal bb', 'fara ressarc', 'favor entr',
#         'favor nom', 'fon facil', 'gent cobr', 'gent vam', 'invest pra',
#         'itau comercializ', 'lex pod', 'lig lig', 'lig to', 'luc carta',
#         'mail pra', 'mant parec', 'minut porr', 'necessari pod',
#         'noit entr', 'nom empr', 'numer atend', 'numer nad', 'numer opca',
#         'numer vers', 'nunc ter', 'obrig atenca', 'obrig respond',
#         'ocorr equip', 'oferec plan', 'oi aqu', 'oi bren', 'oi cheg',
#         'oi entr', 'oi tob', 'oii vc', 'ola cas', 'ola pedr', 'orga regul',
#         'orient amig', 'parec dad', 'pass pra', 'ped amig', 'ped entr',
#         'pedr pod', 'pedr tud', 'plan favor', 'platinum black', 'pod entr',
#         'pod favor', 'pod ped', 'pod verific', 'porr linh', 'posicion entr',
#         'poss ajud', 'possu senh', 'possu tax', 'pra avis', 'pra solic',
#         'pra transfer', 'precis entr', 'precis lig', 'prim chat',
#         'prime empurr', 'pro banc', 'problem pro', 'problem resolv',
#         'question entr', 'real banc', 'realiz entr', 'relat possu',
#         'resolv obrig', 'respond entr', 'ressarc dia', 'retorn entend',
#         'sab numer', 'sac nunc', 'sei entr', 'senh eletron', 'sit ai',
#         'sobr and', 'sobr envi', 'solic codig', 'solicit entr', 'sue carta',
#         'tax vou', 'tent entr', 'ter retorn', 'tiag vam', 'to minut',
#         'tob boa', 'transfer titul', 'trat div', 'tud bem', 'vam entr',
#         'vam verific', 'vao entr', 'vc aind', 'vc pod', 'vc prim',
#         'vc tent', 'verific acontec', 'verific bobby', 'verific carl',
#         'verific cas', 'verific condico', 'verific entr', 'verific equip',
#         'verific numer', 'verific ocorr', 'vers carta', 'vers sue',
#         'vou ped', 'walt assim'],
#        dtype='<U57'),
#  array(['aca cole', 'acus entidad', 'ata stj', 'banc acus', 'boa oportun',
#         'colaboraca justic', 'cole banc', 'cole brasssiiiillll',
#         'cole contr', 'cole jot', 'cole poi', 'comec pag', 'condenaca itau',
#         'contr itau', 'dar ric', 'diminu mil', 'diz estanc', 'entend abus',
#         'entend abusiv', 'entidad defês', 'estanc tant', 'gt tir',
#         'hood robin', 'indenizaca itau', 'indenizaca ser', 'individu comec',
#         'itau aca', 'itau individu', 'itau jot', 'itau milho', 'itau qu',
#         'jus ric', 'mil boa', 'mil colaboraca', 'mil condenaca',
#         'mil diminu', 'mil indenizaca', 'mil mil', 'mil real', 'mil val',
#         'mil vez', 'milho mil', 'milho pra', 'ond vai', 'oportun pra',
#         'pag itau', 'pag pen', 'pei pobr', 'pen privaca', 'pobr dar',
#         'pobr stj', 'poi entend', 'pra mil', 'pra pag', 'privaca liberdad',
#         'qu diz', 'reduz condenaca', 'reduz indenizaca', 'reduz milho',
#         'ric stj', 'robin gt', 'sangr vai', 'ser pag', 'stj reduz',
#         'tant sangr', 'tir pobr', 'vai diferenc', 'vai vaz', 'val aca',
#         'vaz apen', 'vez ond'],
#        dtype='<U57'),
#  array(['boul judiciari', 'diminuica mil', 'gener milho', 'guilherm boul',
#         'indenizaca recent', 'judiciari gener', 'mil diminuica', 'mil vez',
#         'milho mil', 'recent vit', 'recent vitor', 'reduca milho',
#         'retweeted guilherm', 'val indenizaca', 'vez val'],
#        dtype='<U57')]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler(with_mean=False)

std_vector = scaler.fit_transform(raw_vector)
std_vector
# Out:
# <15004x33734 sparse matrix of type '<class 'numpy.float64'>'
# 	with 108415 stored elements in Compressed Sparse Row format>

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
principalComponents = pca.fit_transform(std_vector.toarray())

# %%
principalDf = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2'])

# %%
import matplotlib.pyplot as plt
plt.scatter(principalDf.loc[:,'principal component 1'],principalDf.loc[:,'principal component 2'])
plt.axis([-20,20, -100, 100])
plt.show()
